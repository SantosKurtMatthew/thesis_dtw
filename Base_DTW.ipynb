# %%
import random
import numpy as np
from tslearn.metrics import dtw, dtw_path
from timeit import default_timer as timer

# %%
start = timer()
randomx = []
for i in range(100):
    randomx.append(random.randint(1,1000))
x = np.array(randomx)

randomy = []
for i in range(100):
    randomy.append(random.randint(1,1000))
y = np.array(randomy)

print("DONE GENERATING")
# Out:
# DONE GENERATING

# %%
dtw_score = dtw(x, y)
# Or, if the path is also an important information:
optimal_path, dtw_score = dtw_path(x, y)

# %%
print(dtw_score)
print(optimal_path)
# Out:
# 1917.1397966762884
# [(0, 0), (0, 1), (1, 2), (2, 3), (3, 3), (4, 4), (5, 5), (6, 6), (6, 7), (7, 8), (7, 9), (7, 10), (7, 11), (8, 12), (8, 13), (9, 14), (9, 15), (9, 16), (10, 17), (11, 18), (11, 19), (12, 20), (13, 21), (14, 21), (15, 22), (16, 22), (17, 23), (18, 23), (19, 23), (20, 23), (21, 24), (21, 25), (22, 26), (22, 27), (23, 28), (24, 29), (25, 30), (26, 30), (27, 30), (28, 30), (29, 31), (30, 32), (31, 32), (32, 33), (33, 34), (34, 35), (35, 35), (36, 35), (37, 35), (38, 35), (39, 35), (40, 36), (41, 36), (42, 37), (43, 38), (44, 38), (45, 38), (46, 39), (47, 39), (48, 40), (49, 41), (49, 42), (50, 43), (50, 44), (51, 45), (52, 45), (53, 46), (54, 47), (55, 47), (56, 48), (57, 49), (57, 50), (58, 51), (59, 52), (60, 53), (61, 53), (62, 54), (63, 55), (64, 55), (65, 55), (66, 55), (67, 56), (67, 57), (67, 58), (68, 59), (69, 60), (69, 61), (70, 62), (71, 62), (72, 63), (72, 64), (72, 65), (73, 66), (73, 67), (73, 68), (74, 69), (75, 70), (75, 71), (76, 72), (77, 73), (78, 74), (79, 75), (79, 76), (79, 77), (79, 78), (80, 79), (81, 79), (82, 79), (83, 79), (84, 80), (84, 81), (84, 82), (84, 83), (84, 84), (84, 85), (85, 86), (86, 87), (86, 88), (87, 89), (88, 89), (89, 89), (90, 90), (91, 91), (91, 92), (91, 93), (91, 94), (92, 95), (93, 95), (94, 95), (95, 95), (96, 95), (97, 96), (97, 97), (98, 98), (99, 99)]

# %%
end = timer()
print(end-start)
# Out:
# 11.460010499999044
