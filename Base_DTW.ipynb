# %%
import random
import numpy as np
from tslearn.metrics import dtw, dtw_path
from timeit import default_timer as timer

# %%
start = timer()
randomx = []
for i in range(100):
    randomx.append(random.randint(1,1000))
x = np.array(randomx)

randomy = []
for i in range(100):
    randomy.append(random.randint(1,1000))
y = np.array(randomy)

print("DONE GENERATING")

dtw_score = dtw(x, y)
# Or, if the path is also an important information:
optimal_path, dtw_score = dtw_path(x, y)

print(dtw_score)
print(optimal_path)

end = timer()
print(end-start)
# Out:
# DONE GENERATING
# 1901.1136210126947
# [(0, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 5), (3, 6), (4, 6), (5, 7), (5, 8), (6, 9), (7, 10), (8, 11), (9, 11), (10, 12), (11, 12), (12, 12), (13, 12), (14, 13), (15, 14), (16, 15), (16, 16), (16, 17), (17, 18), (18, 19), (18, 20), (18, 21), (19, 22), (20, 23), (21, 23), (22, 24), (22, 25), (23, 26), (24, 27), (24, 28), (24, 29), (25, 30), (25, 31), (26, 32), (27, 33), (27, 34), (28, 35), (29, 35), (30, 35), (31, 36), (31, 37), (31, 38), (32, 39), (33, 39), (34, 39), (35, 39), (36, 39), (37, 39), (38, 40), (39, 41), (40, 42), (40, 43), (40, 44), (40, 45), (41, 46), (42, 46), (43, 46), (44, 47), (45, 47), (46, 48), (46, 49), (46, 50), (46, 51), (47, 52), (47, 53), (47, 54), (47, 55), (47, 56), (47, 57), (48, 58), (48, 59), (49, 60), (50, 61), (50, 62), (51, 63), (51, 64), (52, 65), (53, 66), (54, 66), (55, 66), (56, 66), (57, 67), (58, 68), (59, 68), (60, 68), (61, 69), (62, 70), (63, 70), (64, 71), (64, 72), (65, 73), (66, 74), (67, 75), (68, 75), (69, 75), (70, 76), (71, 77), (72, 78), (73, 78), (74, 79), (75, 79), (76, 79), (77, 79), (78, 79), (79, 79), (80, 80), (80, 81), (81, 82), (81, 83), (82, 84), (83, 85), (83, 86), (83, 87), (83, 88), (84, 89), (85, 90), (86, 91), (87, 92), (88, 92), (89, 93), (90, 94), (91, 94), (92, 94), (93, 94), (94, 94), (95, 94), (96, 95), (97, 96), (97, 97), (98, 98), (99, 99)]
# 0.003476999991107732
